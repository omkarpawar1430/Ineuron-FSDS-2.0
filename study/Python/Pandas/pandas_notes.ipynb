# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv("addresses.csv")

# %% [markdown]
# CSV stands for "Comma Separated Values". It is a file format used to store and exchange data in a table-like structure. Each line in the file represents a row in the table, and the values in the row are separated by commas. CSV files can be opened and edited in text editors or spreadsheet software such as Microsoft Excel. They are commonly used for data analysis and machine learning applications.

# %%
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# `pandas.core.frame.DataFrame` is a class in the Pandas library that represents a two-dimensional, size-mutable, tabular data structure with labeled axes (rows and columns). It is one of the core data structures in Pandas and is used to store and manipulate data in a variety of formats, such as CSV, Excel, SQL, and more.
#
# A DataFrame consists of rows and columns, where each column can have a different data type. The rows are labeled with an index, which can be either integers or strings, and the columns are also labeled with unique strings called column names. This makes it easy to access and manipulate data in a DataFrame using row and column labels.

# %% [markdown]
# ### Fetching desired data per rows:

# %%
data.head() # Gives first 5 rows of data
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %% [markdown]
# * pandas take first line as header so it is not counted

# %%
data.tail() # gives last five rows of data
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.head(8) # We can give number of rows to extract data from data frame, goes same with data.tail(index)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
# 5   6            6      800 Middle Avenue       NaN    Menlo Park
# 6   7            7         500 Arbor Road       NaN    Menlo Park
# 7   8            8      800 Middle Avenue       NaN    Menlo Park
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US
# 5             CA  94025-9881      US
# 6             CA       94025      US
# 7             CA  94025-9881      US

# %%
data.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns) # Gives list of header basically
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %% [markdown]
# ### Fetching Desired data per column:

# %%
data[['id', 'postal_code', 'city']] # oreder doesn't matter
# Out:
#     id postal_code                 city
# 0    1       94063         Redwood City
# 1    2       94401            San Mateo
# 2    3       94403            San Mateo
# 3    4       94401            San Mateo
# 4    5       94401            San Mateo
# 5    6  94025-9881           Menlo Park
# 6    7       94025           Menlo Park
# 7    8  94025-9881           Menlo Park
# 8    9       94063         Redwood City
# 9   10       94063         Redwood City
# 10  11       94061         Redwood City
# 11  12       94063         Redwood City
# 12  13       94065         Redwood City
# 13  14       94063         Redwood City
# 14  15       94110        San Francisco
# 15  16       94087            Sunnyvale
# 16  17       94080  South San Francisco
# 17  18       94063         Redwood City
# 18  19       94403            San Mateo
# 19  20       94002              Belmont
# 20  21       94103        San Francisco

# %%
data[['id', 'postal_code', 'city']].head(7)
# Out:
#    id postal_code          city
# 0   1       94063  Redwood City
# 1   2       94401     San Mateo
# 2   3       94403     San Mateo
# 3   4       94401     San Mateo
# 4   5       94401     San Mateo
# 5   6  94025-9881    Menlo Park
# 6   7       94025    Menlo Park

# %% [markdown]
# We can also access both desired rows and colums using above trick.

# %% [markdown]
# ### Data Frame Vs Series

# %%
x = data[[ 'city',
 'state_province',
 'postal_code',]].head(3)   # list formate 

x
# Out:
#            city state_province postal_code
# 0  Redwood City             CA       94063
# 1     San Mateo             CA       94401
# 2     San Mateo             CA       94403

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Here we are giving instruction in list formate that's why we get in data frame formate

# %%
y =  data[ 'city',
 'state_province',
 'postal_code'].head(3) # It is not allowed to give in separate way but if
                        #we want only one column we can access it.
y
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('city', 'state_province', 'postal_code')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
y =  data[ 'city'].head(3) # It is not allowed to give in values in a separate way but if
                        #we want only one column we can access it.
y
# Out:
# 0    Redwood City
# 1       San Mateo
# 2       San Mateo
# Name: city, dtype: object

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# The pandas.core.frame.DataFrame class represents a two-dimensional, size-mutable, tabular data structure with labeled axes (rows and columns) in Pandas. On the other hand, pandas.core.series.Series represents a one-dimensional, labeled array that can hold data of any type, such as integers, floats, strings, or objects.
#
# Here are some key differences between DataFrames and Series:
#
# Dimensions: The main difference between DataFrames and Series is that DataFrames have two dimensions (rows and columns), while Series have only one dimension (rows). This means that DataFrames can represent more complex and structured data than Series, which are more suitable for simple arrays.
#
# Indexing: While both DataFrames and Series have row labels, DataFrames also have column labels. This means that DataFrames can be accessed and manipulated using both row and column labels, whereas Series can only be accessed using row labels.
#
# Data types: DataFrames can contain columns of different data types, while Series can only contain data of a single data type. This makes DataFrames more flexible for handling complex data structures.
#
# Data alignment: DataFrames automatically align data based on both row and column labels, while Series align data based on only row labels. This makes it easier to perform arithmetic and logical operations on DataFrames.
#
# In summary, DataFrames are a more complex and powerful data structure in Pandas, designed to handle two-dimensional, labeled data with multiple data types, while Series are a simpler, one-dimensional data structure that is more suitable for working with simple arrays of data with a single data type.

# %% [markdown]
# ### Reading EXCEL file:

# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 96 kB 4.2 MB/s  eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
f = pd.read_excel('airline.xls') # Reads excel file 
f
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
pd.read_excel('airline1.xls','Sheet3') # we can also give sheet name(#! be careful it's casesensitve LOL)
# Out:
#     1960.0000  5.5540     0.4410     0.3193     3.0890     1.4810
# 0        1961      5.465      0.460     0.3079      3.122      1.736
# 1        1962      5.825      0.485     0.3783      3.184      1.926
# 2        1963      6.876      0.506     0.4180      3.263      2.041
# 3        1964      7.823      0.538     0.5163      3.412      1.997
# 4        1965      9.120      0.564     0.5879      3.623      2.257
# 5        1966     10.512      0.586     0.5369      4.074      2.742
# 6        1967     13.020      0.622     0.4443      4.710      3.564
# 7        1968     15.261      0.666     0.3052      5.217      4.767
# 8        1969     16.313      0.731     0.2332      5.569      6.511
# 9        1970     16.002      0.831     0.1883      5.495      7.627
# 10       1971     15.876      0.906     0.2023      5.334      8.673
# 11       1972     16.662      1.000     0.2506      5.345      8.331
# 12       1973     17.014      1.056     0.2668      5.662      8.557
# ...

# %% [markdown]
# Renaming Colums:

# %%
f = pd.read_excel('airline1.xls','Sheet3', header=None, names=['a', 'b', 'c', 'd', 'e', 'f'])

# %%
f
# Out:
#        a       b      c       d      e      f
# 0   1960   5.554  0.441  0.3193  3.089  1.481
# 1   1961   5.465  0.460  0.3079  3.122  1.736
# 2   1962   5.825  0.485  0.3783  3.184  1.926
# 3   1963   6.876  0.506  0.4180  3.263  2.041
# 4   1964   7.823  0.538  0.5163  3.412  1.997
# 5   1965   9.120  0.564  0.5879  3.623  2.257
# 6   1966  10.512  0.586  0.5369  4.074  2.742
# 7   1967  13.020  0.622  0.4443  4.710  3.564
# 8   1968  15.261  0.666  0.3052  5.217  4.767
# 9   1969  16.313  0.731  0.2332  5.569  6.511
# 10  1970  16.002  0.831  0.1883  5.495  7.627
# 11  1971  15.876  0.906  0.2023  5.334  8.673
# 12  1972  16.662  1.000  0.2506  5.345  8.331
# 13  1973  17.014  1.056  0.2668  5.662  8.557
# 14  1974  19.305  1.131  0.2664  5.729  9.508
# 15  1975  18.721  1.247  0.2301  5.722  9.062

# %% [markdown]
# Saving our Changes:

# %%
f.to_csv('new_csv.csv', index=False) # By giving indexes equls to false, the csv file will not be indexed.

# %% [markdown]
# New file gets created and saved in directory.

# %% [markdown]
# ### Fetching data from WEB directly:

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pip install lxml
# Out:
# ...
#      |████████████████████████████████| 7.1 MB 15.0 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
basketball = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
basketball
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(basketball)
# Out:
# list

# %%
basketball[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
basketball[0].to_csv('basketball.csv', index=False)
