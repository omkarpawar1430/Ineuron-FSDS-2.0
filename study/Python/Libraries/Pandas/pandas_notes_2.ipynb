# %% [markdown]
# # Pandas Notes 2

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Understanding your DataSet:

# %%
titanic.dtypes # Gives list of all the columns with it's data type
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.info() # Gives all the info related to dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe() # Gives statistical overveiw of your data for numerical columns by default.
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic[["Name", "Sex", "Cabin", "Ticket", "Embarked"]].describe # for uncategorical / object / str data type
# Out:
# <bound method NDFrame.describe of                                                   Name     Sex Cabin  \
# 0                              Braund, Mr. Owen Harris    male   NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   C85
# 2                               Heikkinen, Miss. Laina  female   NaN
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  C123
# 4                             Allen, Mr. William Henry    male   NaN
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male   NaN
# 887                       Graham, Miss. Margaret Edith  female   B42
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  C148
# 890                                Dooley, Mr. Patrick    male   NaN
#
#                Ticket Embarked
# 0           A/5 21171        S
# 1            PC 17599        C
# ...

# %% [markdown]
# Getting data as per data types:

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %% [markdown]
# we are filtering out data according to our desired datatype

# %%
titanic.dtypes[titanic.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic.dtypes[titanic.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic[titanic.dtypes[titanic.dtypes == 'object'].index] # This way we are able to get data that we needed.
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
titanic[titanic.dtypes[titanic.dtypes == 'object'].index].describe
# Out:
# <bound method NDFrame.describe of                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# ...

# %%
# Mini Assingnement 01:
# # find number males who died 
# my answer:
died = titanic[titanic['Survived']== 0]
died_male = died[died['Sex']=='male']
died_male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# pro answer:
titanic[(titanic['Survived']==0) & (titanic['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Mini Assignment 02:
# Q. Fetch how many number of male and females were on the ship?
# myans:
num_of_males = len(titanic[titanic['Sex'] == 'male'])
num_of_females = len(titanic[titanic['Sex'] == 'female'])
print(f"Number of males onboarded: {num_of_males} \nNumber of females onboarded: {num_of_females}")
# Out:
# Number of males onboarded: 577
# Number of females onboarded: 314

# %%
# pro ans:
titanic["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# Mini Assignment 03:
# Q. Fetch the name of the person who paid highest ?
# proans:

max(titanic['Fare'])
# Out:
# 512.3292

# %%
titanic[titanic['Fare'] == max(titanic['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
titanic[titanic['Fare'] == max(titanic['Fare'])][['Name']]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
# Mini Assignment 04:
# Q. Find how many people got cabin ?
# ans:

# %% [markdown]
# ### For geting Null values:

# %%
len(titanic[titanic['Cabin'].isnull() == False ]) # 204 ppl had cabin
# Out:
# 204

# %% [markdown]
# ### Duplicating Column:

# %%
titanic['New_Col'] = titanic['Name']

# %%
titanic # New_col is added
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Doing Operations on columns:

# %%
titanic['Add_Clm'] = titanic['Survived'] + titanic['Pclass']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %% [markdown]
# ### Deleting column:

# %%
titanic.drop('New_Col', axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# It Does not delete from file, just for temporary:
# 1. Assign above value to variable again to make changes
# 2. use inplace

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
titanic.drop('New_Col', axis=1, inplace=True)

# %%
titanic.head() # New_Col got deleted successfully!!!
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Add_Clm
# 0      0         A/5 21171   7.2500   NaN        S        3
# 1      0          PC 17599  71.2833   C85        C        2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        4
# 3      0            113803  53.1000  C123        S        2
# ...

# %% [markdown]
# ### iloc vs loc: Row wise data fetching

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Add_Clm
# 0      0         A/5 21171   7.2500   NaN        S        3
# 1      0          PC 17599  71.2833   C85        C        2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        4
# 3      0            113803  53.1000  C123        S        2
# ...

# %%
titanic.iloc[0] # tracks using internal indexing
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Add_Clm                              3
# Name: 0, dtype: object

# %%
titanic.loc[1] # Tracks using named indexes where as iloc uses inbuild default indexes
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Add_Clm                                                        2
# Name: 1, dtype: object

# %% [markdown]
# In Pandas, `loc` and `iloc` are two methods for indexing and selecting data in a DataFrame.
#
# `loc` is primarily label-based, which means that you use row and column labels to select data. You can use `loc` to select rows and columns by label, or you can use boolean indexing to select data that meets certain conditions.
#
# On the other hand, `iloc` is primarily integer-based, which means that you use integer indexes to select data. You can use `iloc` to select rows and columns by integer position, or you can use boolean indexing to select data that meets certain conditions.

# %%
titanic.iloc[2:4] # End is excluded
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
#
#              Ticket    Fare Cabin Embarked  Add_Clm
# 2  STON/O2. 3101282   7.925   NaN        S        4
# 3            113803  53.100  C123        S        2

# %% [markdown]
# ### iloc

# %% [markdown]
# # VS

# %% [markdown]
# ### loc

# %%
titanic.loc[101:106] # uses lable indexes - end is included
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 101          102         0       3  Petroff, Mr. Pastcho ("Pentcho")    male
# 102          103         0       1         White, Mr. Richard Frasar    male
# 103          104         0       3        Johansson, Mr. Gustaf Joel    male
# 104          105         0       3    Gustafsson, Mr. Anders Vilhelm    male
# 105          106         0       3             Mionoff, Mr. Stoytcho    male
# 106          107         1       3  Salkjelsvik, Miss. Anna Kristine  female
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Add_Clm
# 101   NaN      0      0   349215   7.8958   NaN        S        3
# 102  21.0      0      1    35281  77.2875   D26        S        1
# 103  33.0      0      0     7540   8.6542   NaN        S        3
# 104  37.0      2      0  3101276   7.9250   NaN        S        3
# 105  28.0      0      0   349207   7.8958   NaN        S        3
# ...

# %%
titanic.loc[101:106, ['Survived', 'Pclass']]
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3

# %%
####################
#  Let's Revise :  #  
####################

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### Know your data:

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Generanl information about dataset:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Statistical Overview of data:
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# For doing subdata analysis:

data[['Name', 'Sex', 'Ticket']].describe()
# Out:
#                            Name   Sex  Ticket
# count                       891   891     891
# unique                      891     2     681
# top     Braund, Mr. Owen Harris  male  347082
# freq                          1   577       7

# %% [markdown]
# ### Comparison | Boolean out put / filtering / conditional :

# %%
data.dtypes
data.dtypes == object 
data.dtypes[data.dtypes == object]
data.dtypes[data.dtypes == object].index
data[data.dtypes[data.dtypes == object].index]
data[data.dtypes[data.dtypes == object].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data[data['survive'] == 0] # Remember CaseSensitivY LOL
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'survive'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data[data["Survived"]== 0].head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         0       3        Allen, Mr. William Henry  male  35.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
data[data["Age"] < 10] # 62 kids below age 10 was on the sheep
# Out:
#        PassengerId   Survived     Pclass        Age      SibSp      Parch  \
# count    62.000000  62.000000  62.000000  62.000000  62.000000  62.000000
# mean    424.741935   0.612903   2.629032   4.083387   1.854839   1.403226
# std     276.898451   0.491062   0.579255   2.834747   1.607837   0.526656
# min       8.000000   0.000000   1.000000   0.420000   0.000000   0.000000
# 25%     183.250000   0.000000   2.000000   2.000000   1.000000   1.000000
# 50%     397.500000   1.000000   3.000000   4.000000   1.000000   1.000000
# 75%     680.250000   1.000000   3.000000   6.000000   3.750000   2.000000
# max     870.000000   1.000000   3.000000   9.000000   5.000000   2.000000
#
#              Fare
# count   62.000000
# mean    30.576679
# std     25.195357
# min      8.516700
# 25%     18.877075
# 50%     27.000000
# 75%     31.387500
# max    151.550000

# %%
data[data['Age'] < 10 & data['Survived'] == 1] # Use () for clean execution of the code
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 data[data['Age'] < 10 & data['Survived'] == 1]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data[(data['Age'] < 10) & (data['Survived'] == 1)].describe() # Only 38 survived...
# Out:
#        PassengerId  Survived     Pclass        Age      SibSp      Parch  \
# count    38.000000      38.0  38.000000  38.000000  38.000000  38.000000
# mean    458.000000       1.0   2.447368   3.478158   0.921053   1.342105
# std     259.918594       0.0   0.601681   2.489255   0.996794   0.534047
# min      11.000000       1.0   1.000000   0.420000   0.000000   0.000000
# 25%     235.000000       1.0   2.000000   1.000000   0.000000   1.000000
# 50%     459.500000       1.0   2.500000   3.000000   1.000000   1.000000
# 75%     713.750000       1.0   3.000000   5.000000   1.000000   2.000000
# max     870.000000       1.0   3.000000   9.000000   4.000000   2.000000
#
#              Fare
# count   38.000000
# mean    27.666995
# std     24.399580
# min      8.516700
# 25%     15.900000
# 50%     21.300000
# 75%     30.790625
# max    151.550000

# %%
# we can also use len funtion on our dataframe:

len(data[(data['Age'] < 10) & (data['Survived'] == 1)])
# Out:
# 38

# %%
# Grouped data count: 

data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# data.info()
data['Pclass'].value_counts() # 1, 2 and 3 class individual count
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# Max and Min 
# max(data['Age'])
 
data[data['Age'] == max(data['Age'])]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
#  min(data['Age']) #OMG
data[data['Age'] == min(data['Age'])]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %% [markdown]
# ### Dealing With Null Values:

# %%
len(data[data['Cabin'].isnull() == False]) # only 2o4 ppl got cabin
# Out:
# 204

# %% [markdown]
# ### Creating Columns:

# %%
data['New_Col'] = 'OM'

# %%
# data.dtypes # By default "New_Col" is object data type
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# New_Col         object
# dtype: object

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Creating copy of column: 
data['New_Class'] = data['Pclass']

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_Col  New_Class
# 0      0         A/5 21171   7.2500   NaN        S      OM          3
# 1      0          PC 17599  71.2833   C85        C      OM          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S      OM          3
# ...

# %%
# Mathematical operations on columns
data["Addition"] = data["Pclass"] + data["Survived"]

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_Col  New_Class  \
# 0      0         A/5 21171   7.2500   NaN        S      OM          3
# 1      0          PC 17599  71.2833   C85        C      OM          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S      OM          3
# ...

# %% [markdown]
# ### Deleting data:

# %%
#data.drop('Addition', axis=1, inplace= True)  
data.drop("New_Col", axis = 1, inplace = True)

# %% [markdown]
# inplace to permenent change in  data

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_Class
# 0      0         A/5 21171   7.2500   NaN        S          3
# 1      0          PC 17599  71.2833   C85        C          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S          3
# 3      0            113803  53.1000  C123        S          1
# ...

# %% [markdown]
# inplace used to commit

# %% [markdown]
# row deletation:

# %%
data = data.drop(0) # Droping row

# %% [markdown]
# # Row handling

# %%
data.iloc[0] # iloc works with defult internal indexing , even we deleted 0 it reoredered again ...
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# New_Class                                                      1
# Name: 1, dtype: object

# %%
data.loc[0] # works with lable index ... we already deleted 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 data.loc[0]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
data.loc[1:4] # note : accessing from 0 is not possible with 0 because no such lable exist...now!!!
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_Class
# 1      0          PC 17599  71.2833   C85        C          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S          3
# 3      0            113803  53.1000  C123        S          1
# 4      0            373450   8.0500   NaN        S          3

# %%
# rows n columns together:
# Case1: 
data.loc[1:4, ['PassengerId', 'Name', 'Sex', 'Age']]
# Out:
#    PassengerId                                               Name     Sex  \
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2            3                             Heikkinen, Miss. Laina  female
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4            5                           Allen, Mr. William Henry    male
#
#     Age
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
# Case2: 
data.loc[[3,5,7, 9], ['PassengerId', 'Name', 'Sex', 'Age']]
# Out:
#    PassengerId                                          Name     Sex   Age
# 3            4  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5            6                              Moran, Mr. James    male   NaN
# 7            8                Palsson, Master. Gosta Leonard    male   2.0
# 9           10           Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %% [markdown]
# ### Let's try using iloc

# %%
data.iloc[[3,5,7, 9], ['PassengerId', 'Name', 'Sex', 'Age']] 
# IndexError: .iloc requires numeric indexers, got ['PassengerId' 'Name' 'Sex' 'Age']
# here column are given as label indexing ... and iloc works with only
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 data.iloc[[3,5,7, 9], ['PassengerId', 'Name', 'Sex', 'Age']]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_Class
# 1      0          PC 17599  71.2833   C85        C          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S          3
# 3      0            113803  53.1000  C123        S          1
# 4      0            373450   8.0500   NaN        S          3
# ...

# %%
data.iloc[[3,5,7, 9], [0, 3, 4, 5]]
# Out:
#     PassengerId                                               Name     Sex  \
# 4             5                           Allen, Mr. William Henry    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
#
#      Age
# 4   35.0
# 6   54.0
# 8   27.0
# 10   4.0

# %%
sub_data = data.iloc[[3,5,7, 9], [0, 3, 4, 5]] 
sub_data.set_index('PassengerId')
# Out:
#                                                      Name     Sex   Age
# PassengerId
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 6                                        Moran, Mr. James    male   NaN
# 8                          Palsson, Master. Gosta Leonard    male   2.0
# 10                    Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
sub_data # No change LOL - use inplace to make change permanent
# Out:
#    PassengerId                                          Name     Sex   Age
# 3            4  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5            6                              Moran, Mr. James    male   NaN
# 7            8                Palsson, Master. Gosta Leonard    male   2.0
# 9           10           Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
sub_data.set_index('PassengerId', inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 sub_data.set_index('PassengerId', inplace= True)
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:6012, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6009                 missing.append(col)
#    6011 if missing:
# -> 6012     raise KeyError(f"None of {missing} are in the columns")
#    6014 if inplace:
# ...

# %%
sub_data
# Out:
#                                                           Name     Sex   Age
# PassengerId
# 5                                     Allen, Mr. William Henry    male  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sub_data2 = data.iloc[ 1:11, [0, 3, 4, 5, 10]]

# %%
sub_data2
# Out:
#     PassengerId                                               Name     Sex  \
# 2             3                             Heikkinen, Miss. Laina  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4             5                           Allen, Mr. William Henry    male
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# 11           12                           Bonnell, Miss. Elizabeth  female
#
#      Age Cabin
# 2   26.0   NaN
# 3   35.0  C123
# 4   35.0   NaN
# 5    NaN   NaN
# 6   54.0   E46
# 7    2.0   NaN
# 8   27.0   NaN
# ...

# %%
sub_data2.dropna() # Drops wherever NaN values are persent in row wise by defualt
# Out:
#     PassengerId                                          Name     Sex   Age  \
# 3             4  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 6             7                       McCarthy, Mr. Timothy J    male  54.0
# 10           11               Sandstrom, Miss. Marguerite Rut  female   4.0
# 11           12                      Bonnell, Miss. Elizabeth  female  58.0
#
#    Cabin
# 3   C123
# 6    E46
# 10    G6
# 11  C103

# %%
sub_data2.dropna(axis=1) # axis = 1 means column and axis = 0 means row (default)
# Out:
#     PassengerId                                               Name     Sex
# 2             3                             Heikkinen, Miss. Laina  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4             5                           Allen, Mr. William Henry    male
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# 11           12                           Bonnell, Miss. Elizabeth  female

# %%
sub_data2.dropna(axis=1,thresh=4) # 4 is threshhold , means there are 4 values present which are not NaN
# Out:
#     PassengerId                                               Name     Sex  \
# 2             3                             Heikkinen, Miss. Laina  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4             5                           Allen, Mr. William Henry    male
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# 11           12                           Bonnell, Miss. Elizabeth  female
#
#      Age Cabin
# 2   26.0   NaN
# 3   35.0  C123
# 4   35.0   NaN
# 5    NaN   NaN
# 6   54.0   E46
# 7    2.0   NaN
# 8   27.0   NaN
# ...

# %%
# Once threshhold crosses 4 column "Cabin" gets deleted
sub_data2.dropna(axis=1,thresh=5)
# Out:
#     PassengerId                                               Name     Sex  \
# 2             3                             Heikkinen, Miss. Laina  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4             5                           Allen, Mr. William Henry    male
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# 11           12                           Bonnell, Miss. Elizabeth  female
#
#      Age
# 2   26.0
# 3   35.0
# 4   35.0
# 5    NaN
# 6   54.0
# 7    2.0
# 8   27.0
# 9   14.0
# 10   4.0
# 11  58.0

# %%
# We can fill NaN values with our value:
sub_data2.fillna('filler_value')
# Out:
#     PassengerId                                               Name     Sex  \
# 2             3                             Heikkinen, Miss. Laina  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4             5                           Allen, Mr. William Henry    male
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# 11           12                           Bonnell, Miss. Elizabeth  female
#
#              Age         Cabin
# 2           26.0  filler_value
# 3           35.0          C123
# 4           35.0  filler_value
# ...

# %%
sub_data2.groupby('Sex').mean()['Age']
# Out:
# /tmp/ipykernel_1061/3558535348.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sub_data2.groupby('Sex').mean()['Age']
# Sex
# female    27.333333
# male      30.333333
# Name: Age, dtype: float64

# %% [markdown]
# # Cocatinating two data sets

# %%
pd.concat([sub_data, sub_data2])
# Out:
#     PassengerId                                               Name     Sex  \
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5             6                                   Moran, Mr. James    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2             3                             Heikkinen, Miss. Laina  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4             5                           Allen, Mr. William Henry    male
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# ...

# %% [markdown]
# ### Using Lambda for efficincey and doing operations on dataset :

# %%
sub_data2['New'] = sub_data2['Age'].apply(lambda x : x -1)
sub_data2
# Out:
#     PassengerId                                               Name     Sex  \
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2             3                             Heikkinen, Miss. Laina  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4             5                           Allen, Mr. William Henry    male
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
#
#      Age Cabin   New
# 1   38.0   C85  37.0
# 2   26.0   NaN  25.0
# 3   35.0  C123  34.0
# 4   35.0   NaN  34.0
# 5    NaN   NaN   NaN
# ...

# %%
# Creating complex function:
def fun1(x):
    return x - 1

# %%
sub_data2['New'] = sub_data2['Age'].apply(fun1)
sub_data2
# Out:
#     PassengerId                                               Name     Sex  \
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2             3                             Heikkinen, Miss. Laina  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4             5                           Allen, Mr. William Henry    male
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
#
#      Age Cabin   New
# 1   38.0   C85  37.0
# 2   26.0   NaN  25.0
# 3   35.0  C123  34.0
# 4   35.0   NaN  34.0
# 5    NaN   NaN   NaN
# ...

# %%
# Another example:
sub_data2['NameSize'] = sub_data2['Name'].apply(len)

# %%
sub_data2
# Out:
#     PassengerId                                               Name     Sex  \
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2             3                             Heikkinen, Miss. Laina  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4             5                           Allen, Mr. William Henry    male
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
#
#      Age Cabin   New  NameSize
# 1   38.0   C85  37.0        51
# 2   26.0   NaN  25.0        22
# 3   35.0  C123  34.0        44
# ...

# %%
def test3(x):
    if x <= 100 :
        return "A"
    elif x >100 and x<200:
        return "B"
    else :
        return "C"
data['Fare_group'] = data['Fare'].apply(test3)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
